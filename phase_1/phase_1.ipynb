# %% [markdown]
# PHASE ONE: PARSING THE NEWS HEADLINES
#
#
#     Objective:Find any city and/or country names mentioned in each of the news headlines.

# %% [markdown]
# WORKFLOW:
#
# Step One
#
#     reference necessary modules:numpy\pandas\unidecode\geonamescache\re\time

# %%
import time
import numpy as np
import pandas as pd
from unidecode import unidecode
import geonamescache
import re

# %% [markdown]
# Step Two
#
#     bringing in external data through geonamescache

# %%
gc = geonamescache.GeonamesCache()
countries_info = gc.get_countries()
us_states_info = gc.get_us_states()
us_counties_info = gc.get_us_counties()
cities_info = gc.get_cities()

# %% [markdown]
# Step Three
#
#     create function1
#     function:get the longest string in the list

# %%
def longest_str(original_list):
    if original_list:
        result = original_list[0]
        for i in original_list:
            if len(i) > len(result):
                result = i
        return result
    else:
        return None

# %% [markdown]
# Step Four
#
#     create function2
#     function:find any country names mentioned in each of the news headlines through regular expressions
#     Notice:We entere the title and the official city name and return the value are already unicode.This function is called after match_city_country is called.

# %%
def match_country_from_headline(headline, original_country_name):
    matched_country = []
    for country_entry_value in countries_info.values():
        country_name = unidecode(country_entry_value['name']).strip()
        compiled_normalized_name = re.compile(r'\b' + re.escape(country_name) + r'\b')
        country_name_matches = compiled_normalized_name.findall(headline)
        if country_name_matches:
            matched_country.append(country_name_matches[0])
    if matched_country:
        return longest_str(matched_country)
    else:
        return original_country_name

# %% [markdown]
# Step Four
#
#     create function3
#     function:match cities by title and preliminary match countries
#     Notice:The title is passed in unicode and the return value is unicode.This function is called before the match_country_from_headline function

# %%
counter_match_city = 0
def match_city_country(headline):
    global counter_match_city
    counter_match_city += 1
    print('begin to match headline {}: {}'.format(counter_match_city, headline))

    matched_city = {}
    for city_ID, city_entry_value in cities_info.items():
        city_names = [unidecode(city_entry_value['name']).strip()]
        for alternate in city_entry_value['alternatenames']:
            striped_normalized_alternate = unidecode(alternate).strip()
            if striped_normalized_alternate:
                city_names.append(striped_normalized_alternate)
        for name in city_names:
            compiled_normalized_name = re.compile(r'\b' + re.escape(name) + r'\b')
            city_name_matches = compiled_normalized_name.findall(headline)
            if city_name_matches:
                matched_city[city_ID] = [city_name_matches[0], city_names[0], len(city_entry_value['alternatenames']),
                                         city_entry_value['population']]
    if matched_city:
        # First, find the longest match. If the longest match is of the same length, choose the official city name instead of the nickname. If still cannot choose, choose the city with more nicknames, and if still cannot choose, choose the city with more people, for the nickname number and population reflect city fame and reputation.  
        # Find the longest match and the longest matching length. Remove the other match
        max_length = 0
        for skimmed_city_info in matched_city.values():
            max_length = max(max_length, len(skimmed_city_info[0]))
        has_formal_name = False
        delete_ID = []
        for city_ID, skimmed_city_info in matched_city.items():
            if len(skimmed_city_info[0]) < max_length:
                delete_ID.append(city_ID)
            else:
                if skimmed_city_info[0] == skimmed_city_info[1]:
                    has_formal_name = True
        for id in delete_ID:
            matched_city.pop(id)
        delete_ID.clear()

        # If there are formal names, remove other informal ones
        if has_formal_name:
            for city_ID, skimmed_city_info in matched_city.items():
                if skimmed_city_info[0] != skimmed_city_info[1]:
                    delete_ID.append(city_ID)
            for id in delete_ID:
                matched_city.pop(id)
            delete_ID.clear()

        # Delete cities with a low number of nicknames. The nicknames can reflect a city's cultural influence  
        max_num_alternate = 0
        for skimmed_city_info in matched_city.values():
            max_num_alternate = max(max_num_alternate, skimmed_city_info[2])
        for city_ID, skimmed_city_info in matched_city.items():
            if skimmed_city_info[2] < max_num_alternate:
                delete_ID.append(city_ID)
        for id in delete_ID:
            matched_city.pop(id)
        delete_ID.clear()

        # Returns the largest population of the remaining matches. The population can also indicate the influence of the city  
        max_population = 0
        for skimmed_city_info in matched_city.values():
            max_population = max(max_population, skimmed_city_info[3])
        for city_ID, skimmed_city_info in matched_city.items():
            if skimmed_city_info[3] == max_population:
                country_name = countries_info[cities_info[city_ID]['countrycode']]['name']
                return skimmed_city_info[1], unidecode(country_name).strip()

    matched_us_state = []
    for us_state_entry_value in us_states_info.values():
        compiled_state_name = re.compile(r'\b' + re.escape(us_state_entry_value['name']) + r'\b')
        state_name_matches = compiled_state_name.findall(headline)
        if state_name_matches:
            matched_us_state.append(state_name_matches[0])
    if matched_us_state:
        return longest_str(matched_us_state), 'United States'

    # There are more us_counties with the same name, but it doesn't matter for the corresponding countries are all United States  
    matched_us_county = []
    for county_info in us_counties_info:
        compiled_county_name = re.compile(r'\b' + re.escape(county_info['name']) + r'\b')
        county_name_matches = compiled_county_name.findall(headline)
        if county_name_matches:
            matched_us_county.append(county_name_matches[0])
    if matched_us_county:
        return longest_str(matched_us_county), 'United States'
    return None, None

# %% [markdown]
# Step Five
#
#     create function4
#     function:put the extracted data into a pandas DataFrame with three columns: headline, city, country.

# %%
def read_and_extract_headline_data(start, end=None):
    result = np.genfromtxt("database/headlines.txt", 'str', delimiter='\n', encoding='utf-8')
    result = pd.DataFrame(result, columns=['headline'], dtype='str')
    result.drop_duplicates(ignore_index=True, inplace=True)
    if end is None:
        result = result.iloc[start:].reset_index(drop=True)
    else:
        result = result.iloc[start:end].reset_index(drop=True)
    result['headline'] = result['headline'].apply(unidecode)
    num_headline = len(result)

    result['city'], result['country'] = None, None
    for i in range(num_headline):
        result.loc[i, 'city'], result.loc[i, 'country'] = match_city_country(result.loc[i, 'headline'])
        result.loc[i, 'country'] = match_country_from_headline(result.loc[i, 'headline'], result.loc[i, 'country'])
    return result

# %% [markdown]
# Step Six
#
#     create function5
#     function:build the main function. Save the result as a CSV file

# %%
def main():
    result = read_and_extract_headline_data(0)
    result.to_csv('database/extracted_data.csv', index=False, encoding='utf-8')

    print(result.describe())
    print(result.info())
    print(result[result.isnull().T.any()])

# %% [markdown]
# Step Six
#
#     create function6
#     function:calculate the running time based on seconds alone

# %%
if __name__ == "__main__":
    timestamp1 = time.time()
    main()
    timestamp2 = time.time()
    print("总共用时 %f 秒" % (timestamp2 - timestamp1))
# Out:
# begin to match headline 1: Zika Outbreak Hits Miami
# begin to match headline 2: Could Zika Reach New York City?
# begin to match headline 3: First Case of Zika in Miami Beach
# begin to match headline 4: Mystery Virus Spreads in Recife, Brazil
# begin to match headline 5: Dallas man comes down with case of Zika
# begin to match headline 6: Trinidad confirms first Zika case
# begin to match headline 7: Zika Concerns are Spreading in Houston
# begin to match headline 8: Geneve Scientists Battle to Find Cure
# begin to match headline 9: The CDC in Atlanta is Growing Worried
# begin to match headline 10: Zika Infested Monkeys in Sao Paulo
# begin to match headline 11: Brownsville teen contracts Zika virus
# begin to match headline 12: Mosquito control efforts in St. Louis take new tactics with Zika threat
# begin to match headline 13: San Juan reports 1st U.S. Zika-related death amid outbreak
# begin to match headline 14: Flu outbreak in Galveston, Texas
# begin to match headline 15: Zika alert a Manila now threatened
# begin to match headline 16: Zika afflicts 7 in Iloilo City
# begin to match headline 17: New Los Angeles Hairstyle goes Viral
# begin to match headline 18: Louisiana Zika cases up to 26
# begin to match headline 19: Orlando volunteers aid Zika research
# begin to match headline 20: Zika infects pregnant woman in Cebu
# begin to match headline 21: Chicago's First Zika Case Confirmed
# begin to match headline 22: Tampa Bay Area Zika Case Count Climbs
# begin to match headline 23: Bad Water Leads to Sickness in Flint, Michigan
# begin to match headline 24: Baltimore plans for Zika virus
# begin to match headline 25: London Health Unit Tracks Mad Cow Disease
# begin to match headline 26: Zika cases in Vietnam's Ho Chi Minh City surge
# begin to match headline 27: Philadelphia experts track pandemic
# begin to match headline 28: Flu season hits Boston
# begin to match headline 29: Scientists in Paris to look for answers
# begin to match headline 30: Key Zika Findings in San Diego Institute
# begin to match headline 31: Thailand-Zika Virus in Bangkok
# begin to match headline 32: Beijing team cracks Zika secret
# begin to match headline 33: Zika spreading to Salvador
# begin to match headline 34: Kuala Lumpur is Hit By Zika Threat
# begin to match headline 35: First Zika case confirmed in Yangon
# begin to match headline 36: Tallahassee Doctors Discuss Zika Virus
# begin to match headline 37: Zika Virus Reaches San Francisco
# begin to match headline 38: New Vaccine on Trial in Bethesda District
# begin to match headline 39: Townsville Zika tests inconclusive
# begin to match headline 40: Mandaluyong City under Siege by Virus
# begin to match headline 41: Hepatitis E re-emerges in Santa Rosa
# begin to match headline 42: Zika worries in San Salvador
# begin to match headline 43: Zika virus reported in Cleveland
# begin to match headline 44: More Zika patients reported in Austin
# begin to match headline 45: Zika outbreak in Piracicaba, Brazil
# begin to match headline 46: Lima tries to address Zika Concerns
# begin to match headline 47: More people in Toronto are infected with Hepatitis E every year
# begin to match headline 48: 18 new Zika Cases in Bogota
# begin to match headline 49: Spanish Flu Sighted in Antigua
# begin to match headline 50: Brisbane is infested with Meningitis
# begin to match headline 51: Cholera outbreak in Dakar
# begin to match headline 52: Zika Virus Transmission Detected in Havana
# begin to match headline 53: Zika symtomps spotted in Key West
# begin to match headline 54: Case of Measles Reported in Vancouver
# begin to match headline 55: Seattle scientists get $500,000 grant to pursue Zika vaccine New 7:50 pm
# begin to match headline 56: Nashville takes precautions against Zika
# begin to match headline 57: Saint Croix under Zika threat
# begin to match headline 58: Fort Collins Encounters Severe Symptoms of Gonorrhea
# begin to match headline 59: Zika surfaces in Klang, Malaysia
# begin to match headline 60: Rumors about Meningitis spreading in Guatemala City have been refuted
# begin to match headline 61: Madison lab developing vaccine against Zika virus [The Wisconsin State Journal]
# begin to match headline 62: New Zika Case Confirmed in Sarasota County
# begin to match headline 63: Lower Hospitalization in Entebbe after Rabies Vaccine becomes Mandatory
# begin to match headline 64: Carnival under threat in Rio De Janeiro due to Zika outbreak
# begin to match headline 65: Second Zika Paitient in Brasilia
# begin to match headline 66: Jacksonville man hit by Zika
# begin to match headline 67: Schools in Shenzhen Closed Due to Malaria Outbreak
# begin to match headline 68: Caracas patient dies
# begin to match headline 69: More Quezon City Zika Transmissions
# begin to match headline 70: Schools in Sydney Closed Due to Respiratory Syncytial Virus Outbreak
# begin to match headline 71: Mumbai's Health Minister warns of more Zika cases
# begin to match headline 72: Pune woman diagnosed with Zika
# begin to match headline 73: Hospitals in Hanoi fill up with Zika patients
# begin to match headline 74: Zika case reported in Oton
# begin to match headline 75: Authorities are Worried about the Spread of Bronchitis in Silver Spring
# begin to match headline 76: Zika: Delhi for strict monitoring
# begin to match headline 77: Hillsborough uses innovative trap against Zika 20 minutes ago
# begin to match headline 78: Belize City under threat from Zika
# begin to match headline 79: Student sick in Campinas, Brazil
# begin to match headline 80: More Zika cases in Soyapango
# begin to match headline 81: Authorities are Worried about the Spread of Mad Cow Disease in Rome
# begin to match headline 82: Seoul confirms 14th Zika infection
# begin to match headline 83: Hepatitis B Vaccine is now Required in Quebec
# begin to match headline 84: Zika outbreak spreads to Mexico City
# begin to match headline 85: Rochester authorities confirmed the spread of Dengue
# begin to match headline 86: El Paso fighting Zika
# begin to match headline 87: Visitor to Cucuta contracts Zika
# begin to match headline 88: Zika now spreading through Jakarta
# begin to match headline 89: Maka City Experiences Influenza Outbreak
# begin to match headline 90: Salt Lake City tests new cure for Respiratory Syncytial Virus
# begin to match headline 91: Zika San Antonio Patient Speaks Out
# begin to match headline 92: Ebola outbreak in Kampala
# begin to match headline 93: Precautionary Zika measures in Rockhampton
# begin to match headline 94: Zika arrives in Tegucigalpa
# begin to match headline 95: New Zika Case Confirmed in Belo Horizonte
# begin to match headline 96: Case of Hepatitis E Reported in Melbourne
# begin to match headline 97: First Columbus Zika case
# begin to match headline 98: New medicine wipes out Tuberculosis in Taipei
# begin to match headline 99: Zika Patient in Seminole, Florida
# begin to match headline 100: Antipolo under threat from Zika Virus
# begin to match headline 101: Spreading Zika reaches Bacoor
# begin to match headline 102: Can Zika make it here to Vero Beach?
# begin to match headline 103: Zika afflicts patient in Calamba
# begin to match headline 104: Hollywood Outbreak Film Premieres
# begin to match headline 105: Petaling Jaya man ill from Zika
# begin to match headline 106: Malaria is Spreading in Johannesburg
# begin to match headline 107: Authorities are Worried about the Spread of Norovirus in Buenos Aires
# begin to match headline 108: Guangzhou Patient in Critical Condition after Contracting Swine Flu
# begin to match headline 109: Doral hit by Deadly Virus
# begin to match headline 110: Tokyo Encounters Severe Symptoms of Meningitis
# begin to match headline 111: Rabies Exposure in Hamilton
# begin to match headline 112: Authorities are Worried about the Spread of Influenza in Savannah
# begin to match headline 113: Zika Outbreak in Hyderabad
# begin to match headline 114: Birmingham Residents Recieve Rabies vaccine
# begin to match headline 115: Is Zika virus in Majuro?
# begin to match headline 116: Spreading Zika ruining Cancun fun
# begin to match headline 117: Cancun hit by Outbreak of Party Fever!
# begin to match headline 118: HIV has Arrived in Fairfax
# begin to match headline 119: Spanish Flu Outbreak in Barcelona
# begin to match headline 120: Santa Barbara tests new cure for Hepatitis C
# begin to match headline 121: Spring break ruined by Zika in Fort Lauderdale
# begin to match headline 122: Villavicencio under Zika threat
# begin to match headline 123: Two more Zika cases confirmed in Laredo
# begin to match headline 124: New Delhi Addressing Zika Concerns
# begin to match headline 125: New Zika Case in Kota Kinabalu, Malaysia
# begin to match headline 126: New medicine wipes out West Nile Virus in Ventura
# begin to match headline 127: Meningitis re-emerges in Nassau
# begin to match headline 128: Zika reaches Johor Bahru, Malaysia
# begin to match headline 129: Nha Trang Zika Outbreak
# begin to match headline 130: First Zika Case in Cincinnati
# begin to match headline 131: Molo Cholera Spread Causing Concern
# begin to match headline 132: Norovirus Exposure in Hong Kong
# begin to match headline 133: 19 new Zika Cases in Sengkang
# begin to match headline 134: Zika cases concern Charlotte residents
# begin to match headline 135: Batangas Tourism Takes a Hit as Virus Spreads
# begin to match headline 136: Johannesburg Patient in Critical Condition after Contracting Pneumonia
# begin to match headline 137: Outbreak of Zika in Bacolod City
# begin to match headline 138: Respiratory Syncytial Virus Keeps Spreading in Masaya
# begin to match headline 139: Spike of Pneumonia Cases in Springfield
# begin to match headline 140: More Zika patients reported in Mcallen
# begin to match headline 141: Zika case reported in Jupiter
# begin to match headline 142: Zika virus confirmed in Westchester
# begin to match headline 143: Authorities are Worried about the Spread of Tuberculosis in Abuja
# begin to match headline 144: Rumors about Hepatitis D Spreading in San Juan Capistrano have been Refuted
# begin to match headline 145: The Spread of Measles in Spokane has been Confirmed
# begin to match headline 146: Zika alert for Rio Grande Valley residents
# begin to match headline 147: Zika symptoms spotted in Colombo
# begin to match headline 148: West Nile Virus Outbreak in Louisville
# begin to match headline 149: New details in Baton Rouge cop killings
# begin to match headline 150: Hepatitis B has not Left Florence
# begin to match headline 151: More Zika patients reported in Pensacola
# begin to match headline 152: Outbreak of Zika in Corpus Christi
# begin to match headline 153: How to Avoid Rhinovirus in Lemon Grove
# begin to match headline 154: Rumors about Rotavirus spreading in Huntsville have been refuted
# begin to match headline 155: Rhinovirus has Arrived in Athens
# begin to match headline 156: Outbreak of Zika in Panama City
# begin to match headline 157: West Nile Virus Outbreak in Saint Johns
# begin to match headline 158: Measles has not Left Brooklyn
# begin to match headline 159: Escondido neighborhood to get sprayed for Zika virus
# begin to match headline 160: Zika in Belmont, Belmont worry
# begin to match headline 161: Influenza has not Left Sacramento
# begin to match headline 162: Veracruz hit by Zika Concerns
# begin to match headline 163: Case of Mumps Reported in Dayton
# begin to match headline 164: Authorities are Worried about the Spread of Dengue in Kingston
# begin to match headline 165: Gainesville Deals with Disease Concerns
# begin to match headline 166: Montevideo Encounters Severe Symptoms of Rotavirus
# begin to match headline 167: Varicella Keeps Spreading in Detroit
# begin to match headline 168: Arhus is infested with Bronchitis
# begin to match headline 169: Zika Troubles come to Niteroi
# begin to match headline 170: Zika cases in Singapore reach 393
# begin to match headline 171: Manhattan Residents Recieve HIV vaccine
# begin to match headline 172: Zika arrives in Miri
# begin to match headline 173: Rumors about Dengue Spreading in Syracuse have been Refuted
# begin to match headline 174: Will Norovirus vaccine help Raleigh?
# begin to match headline 175: Lower Hospitalization in Auckland after Hepatitis D Vaccine becomes Mandatory
# begin to match headline 176: How to Avoid Gonorrhea in Shreveport
# begin to match headline 177: Ithaca is infested with Dengue
# begin to match headline 178: Will MCD vaccine help Strasbourg?
# begin to match headline 179: New medicine wipes out Measles in Fresno
# begin to match headline 180: BREAKING a Zika in Missoula
# begin to match headline 181: Zika arrives in Santos
# begin to match headline 182: Sick Livestock Leads to Serious Trouble for Belfort
# begin to match headline 183: Hepatitis E has not Left Libreville
# begin to match headline 184: New medicine wipes out Chikungunya in Tucson
# begin to match headline 185: Norovirus has Arrived in Winnipeg
# begin to match headline 186: Hepatitis B Comes to Kansas City
# begin to match headline 187: More Patients in Cambridge are Getting Diagnosed with Chickenpox
# begin to match headline 188: Chikungunya Exposure in Toledo
# begin to match headline 189: Is Lafayette prepared to combat Zika?
# begin to match headline 190: Mecca tests new cure for Chikungunya
# begin to match headline 191: Zika arrives in San Benito
# begin to match headline 192: Syphilis Outbreak in Harrisburg
# begin to match headline 193: Zika Arrives in North Miami
# begin to match headline 194: Urbana Encounters Severe Symptoms of Meningitis
# begin to match headline 195: Pittsburgh Residents Recieve Norovirus vaccine
# begin to match headline 196: Chikungunya Hits Denver
# begin to match headline 197: Zika case recorded in Tunapuna A>>
# begin to match headline 198: Spike of Respiratory Syncytial Virus Cases in Mandalay
# begin to match headline 199: HIV Keeps Spreading in Boulder
# begin to match headline 200: More Zika patients reported in Joao Pessoa
# begin to match headline 201: Will Tuberculosis vaccine help Rockville?
# begin to match headline 202: Mad Cow Disease Re-emerges in Chatham
# begin to match headline 203: Zika Virus Arrives in Ontario
# begin to match headline 204: Mad Cow Disease Hits Naples
# begin to match headline 205: More Zika patients reported in Davao
# begin to match headline 206: The Spread of Chikungunya in Arcadia has been Confirmed
# begin to match headline 207: Oxford tests new cure for HIV
# begin to match headline 208: Outbreak of Zika in Stephenville
# begin to match headline 209: Providence Encounters Severe Symptoms of Dengue
# begin to match headline 210: Tests negative on Windsor Zika carriers
# begin to match headline 211: Zika battle outlined at Valdosta meeting
# begin to match headline 212: Zika case reported in Coral Gables
# begin to match headline 213: Hepatitis C Outbreak in Danbury
# begin to match headline 214: Chickenpox has Arrived in Chula Vista
# begin to match headline 215: Syphilis Hits Jefferson
# begin to match headline 216: Will HIV vaccine help Las Vegas?
# begin to match headline 217: Zika arrives in West Palm Beach
# begin to match headline 218: Mobile authorities confirmed the spread of Bronchitis
# begin to match headline 219: Zika spreads to Daytona Beach
# begin to match headline 220: Lausanne Residents Recieve Meningitis vaccine
# begin to match headline 221: Rhinovirus Comes to San Jose
# begin to match headline 222: Spike of Chlamydia Cases in Farmington
# begin to match headline 223: Authorities are Worried about the Spread of Rotavirus in Union
# begin to match headline 224: Rumors about Hepatitis D spreading in Albany have been refuted
# begin to match headline 225: Zika symptoms spotted in Bello
# begin to match headline 226: Will Meningitis vaccine help Hamburg?
# begin to match headline 227: Madera Patient in Critical Condition after Contracting Rabies
# begin to match headline 228: Zika Virus Detected in Lubbock
# begin to match headline 229: Malaria re-emerges in Boise
# begin to match headline 230: Varicella re-emerges in Lagos
# begin to match headline 231: Vericella spreading in Ibadan
# begin to match headline 232: Schools in Birmingham Closed Due to Measles Outbreak
# begin to match headline 233: How to Avoid Hepatitis B in Waldorf
# begin to match headline 234: More people in Mclean are infected with Hepatitis A every year
# begin to match headline 235: Malaria Exposure in Sussex
# begin to match headline 236: Tuberculosis Outbreak in Newark
# begin to match headline 237: Zika Virus Sparks 'International Concern'
# begin to match headline 238: Spike of Chlamydia Cases in Berlin
# begin to match headline 239: Zika-carrying mosquitoes discovered in Ardmore
# begin to match headline 240: Zika Mosquitoes May Have Bred in Bromeliads, Florida Officials Say
# begin to match headline 241: More Livestock in Fontainebleau are infected with Mad Cow Disease
# begin to match headline 242: Frisco Woman Tests Positive For Zika Virus
# begin to match headline 243: Authorities are Worried about the Spread of Norovirus in Dubai
# begin to match headline 244: Benton Residents Recieve Pneumonia vaccine
# begin to match headline 245: Case of Hepatitis A Reported in Calgary
# begin to match headline 246: Zika Outbreak in Pinewood
# begin to match headline 247: Will Swine Flu vaccine help Ljubljana?
# begin to match headline 248: Bronchitis re-emerges in Tehran
# begin to match headline 249: Greenwich Establishes Zika Task Force
# begin to match headline 250: Mad Cow case in Murcia
# begin to match headline 251: Mad Cow Disease Spreads to Margate
# begin to match headline 252: Zika Strikes St. Petersburg
# begin to match headline 253: Will West Nile Virus vaccine help Parsons?
# begin to match headline 254: Will the Mad Cow Outbreak Reach Vienna?
# begin to match headline 255: More Patients in Orange are Getting Diagnosed with Chickenpox
# begin to match headline 256: Lower Hospitalization in Richmond after Mumps Vaccine becomes Mandatory
# begin to match headline 257: Meningitis re-emerges in Medina
# begin to match headline 258: Yulee takes a hit from Spreading Sickness
# begin to match headline 259: Four cases of Zika in Hidalgo County
# begin to match headline 260: Zika symptoms spotted in Hollywood
# begin to match headline 261: Zika arrives in Oaxaca
# begin to match headline 262: More people in Durham are infected with Chlamydia every year
# begin to match headline 263: Authorities are Worried about the Spread of Gonorrhea in Taoyuan City
# begin to match headline 264: Swine Flu re-emerges in La Jolla
# begin to match headline 265: Tuberculosis Outbreak in Hartford
# begin to match headline 266: Rumors about Mumps Spreading in New Bedford have been Refuted
# begin to match headline 267: Respiratory Syncytial Virus Vaccine is now Required in Tulsa
# begin to match headline 268: More people in Indianapolis are infected with Norovirus every year
# begin to match headline 269: Lower Hospitalization in Dhaka after Measles Vaccine becomes Mandatory
# begin to match headline 270: Albany Residents Recieve Respiratory Syncytial Virus vaccine
# begin to match headline 271: The Spread of Chikungunya in Davidson has been Confirmed
# begin to match headline 272: Rotavirus Vaccine is now Required in Starkville
# begin to match headline 273: Schools in Yaounde Closed Due to Mumps Outbreak
# begin to match headline 274: More people in Nadi are infected with HIV every year
# begin to match headline 275: Tocumen tests new cure for Hepatitis A
# begin to match headline 276: Phnom Penh hit by Zika Threat
# begin to match headline 277: Zika Troubles come to Harlingen
# begin to match headline 278: Zika spreads to Barranquilla
# begin to match headline 279: Milwaukee authorities confirmed the spread of Rhinovirus
# begin to match headline 280: Mad Cow Disease Hits Rotterdam
# begin to match headline 281: Zika symptoms spotted in Arlington
# begin to match headline 282: West Nile Virus Hits Yogyakarta
# begin to match headline 283: More Patients in Dublin are Getting Diagnosed with Bronchitis
# begin to match headline 284: Rumors about Tuberculosis Spreading in Baud have been Refuted
# begin to match headline 285: Rumors about West Nile Virus Spreading in Salem have been Refuted
# begin to match headline 286: St. Catharines Patient in Critical Condition after Contracting Dengue
# begin to match headline 287: Zika case reported in Los Fresnos
# begin to match headline 288: More Zika patients reported in Camacari
# begin to match headline 289: Outbreak of Zika in Pasig City
# begin to match headline 290: Zika Troubles come to Kampong Cham
# begin to match headline 291: Zika case reported in Rizal
# begin to match headline 292: Zika Spreads to Palm Beach Gardens
# begin to match headline 293: More people in Saint Petersburg are infected with Varicella every year
# begin to match headline 294: Spike of Herpes Cases in Meriden
# begin to match headline 295: Zika case reported in Abilene
# begin to match headline 296: Outbreak of Zika in Palm Springs
# begin to match headline 297: Halifax is infested with Swine Flu
# begin to match headline 298: Zika arrives in Natal
# begin to match headline 299: Herpes Keeps Spreading in Rochester
# begin to match headline 300: Zika case reported in Phetchabun
# begin to match headline 301: How to Avoid Pneumonia in Bullhead City
# begin to match headline 302: West Nile Virus re-emerges in Wellington
# begin to match headline 303: Rumors about Pneumonia spreading in Ottawa have been refuted
# begin to match headline 304: Meningitis re-emerges in Summerville
# begin to match headline 305: Pneumonia Symptoms Spread all over Bloomington
# begin to match headline 306: More Patients in Stuttgart are Getting Diagnosed with Rabies
# begin to match headline 307: Schools in Glasgow Closed Due to Hepatitis B Outbreak
# begin to match headline 308: Phoenix Residents Recieve Syphilis vaccine
# begin to match headline 309: More people in Boucau are infected with HIV every year
# begin to match headline 310: Spanish flu spreading in Madrid
# begin to match headline 311: Rabies Hits Madrid
# begin to match headline 312: Zika Outbreak in Weslaco
# begin to match headline 313: How to Avoid Chlamydia in Santiago
# begin to match headline 314: Rotavirus Vaccine is now Required in Las Cumbres
# begin to match headline 315: Mumps Symptoms Spread all over Jefferson
# begin to match headline 316: Mad Cow Outbreak Spreading in Ennis
# begin to match headline 317: Southampton Patient in Critical Condition after Contracting Tuberculosis
# begin to match headline 318: The Spread of Rhinovirus in Boardman has been Confirmed
# begin to match headline 319: Richland Center is infested with Hepatitis B
# begin to match headline 320: Authorities are Worried about the Spread of Chickenpox in Richmond
# begin to match headline 321: Chikungunya re-emerges in Kobe
# begin to match headline 322: Malaria Vaccine is now Required in Schenectady
# begin to match headline 323: Hepatitis D has Arrived in Grenoble
# begin to match headline 324: West Nile Virus Symptoms Spread all over Yerevan
# begin to match headline 325: Zika Outbreak in Sincelejo
# begin to match headline 326: Rumors about HIV spreading in Montpellier have been refuted
# begin to match headline 327: Praia tests new cure for Pneumonia
# begin to match headline 328: Bronchitis Outbreak in Manhasset
# begin to match headline 329: Lower Hospitalization in Lakewood after Hepatitis B Vaccine becomes Mandatory
# begin to match headline 330: Zika spreads to Kuching
# begin to match headline 331: Spike of Rotavirus Cases in Omaha
# begin to match headline 332: Tuberculosis re-emerges in Silver Springs
# begin to match headline 333: Will West Nile Virus vaccine help Coronado?
# begin to match headline 334: Zika case confirmed in Lorain
# begin to match headline 335: Chickenpox Hits Simpsonville
# begin to match headline 336: Framingham Residents Receive Measles vaccine
# begin to match headline 337: Rumors about Mad Cow Disease Brighton have been Refuted
# begin to match headline 338: Zika case reported in Jacobina
# begin to match headline 339: Bridgeport authorities confirmed the spread of West Nile Virus
# begin to match headline 340: Zika Troubles come to Padre Las Casas
# begin to match headline 341: Measles Vaccine is now Required in Wailuku
# begin to match headline 342: Zika symptoms spotted in Surat
# begin to match headline 343: Rumors about Influenza Spreading in Dobbs Ferry have been Refuted
# begin to match headline 344: More contaminated cattle reported in Bedford
# begin to match headline 345: Zika in Tamarac!
# begin to match headline 346: Will Measles vaccine help Milford?
# begin to match headline 347: Spike of Norovirus Cases in Huddersfield
# begin to match headline 348: Rhinovirus Hits Bakersfield
# begin to match headline 349: Lower Hospitalization in Papeete after Measles Vaccine becomes Mandatory
# begin to match headline 350: Zika arrives in Udon Thani
# begin to match headline 351: Spike of Dengue Cases in Stockholm
# begin to match headline 352: More people in Berkeley are infected with Swine Flu every year
# begin to match headline 353: Outbreak of Zika in Destin
# begin to match headline 354: Zika only the latest mosquito-borne threat to New Orleans
# begin to match headline 355: Will Swine Flu vaccine help Annapolis?
# begin to match headline 356: Lower Hospitalization in Monroe after Hepatitis D Vaccine becomes Mandatory
# begin to match headline 357: New medicine wipes out Dengue in Saginaw
# begin to match headline 358: Spike of Rhinovirus Cases in Sevierville
# begin to match headline 359: Duisburg up in Arms over Mad Cow Disease
# begin to match headline 360: New medicine wipes out Mumps in Saint Charles
# begin to match headline 361: Case of Chikungunya Reported in Gaithersburg
# begin to match headline 362: How to Avoid Respiratory Syncytial Virus in San Bernardino
# begin to match headline 363: Laventille authorities confirmed the spread of Rhinovirus
# begin to match headline 364: More Zika patients reported in Waco
# begin to match headline 365: Will Herpes vaccine help Newcastle?
# begin to match headline 366: Erie County sets Zika traps
# begin to match headline 367: More people in Huron are infected with Dengue every year
# begin to match headline 368: How to Avoid Norovirus in Greenville
# begin to match headline 369: More Zika patients reported in Calumpang
# begin to match headline 370: Zika symptoms spotted in Quisqueya
# begin to match headline 371: Rumors about Hepatitis D Spreading in Montreal have been Refuted
# begin to match headline 372: Zika symptoms spotted in Fortaleza
# begin to match headline 373: Rumors about Bronchitis spreading in Bundaberg have been refuted
# begin to match headline 374: Hepatitis A re-emerges in Stamford
# begin to match headline 375: Schools in Huntington Closed Due to Rotavirus Outbreak
# begin to match headline 376: Will Mad Cow Vaccine Help Bristol?
# begin to match headline 377: Chickenpox Comes to Stillwater
# begin to match headline 378: The Spread of Meningitis in Imperial has been Confirmed
# begin to match headline 379: Will Tuberculosis vaccine help Cherry Creek?
# begin to match headline 380: Gympie Patient in Critical Condition after Contracting Chlamydia
# begin to match headline 381: Case of Measles Reported in Springdale
# begin to match headline 382: Norwalk Encounters Severe Symptoms of Malaria
# begin to match headline 383: Zika arrives in Orange City
# begin to match headline 384: Pilsen Encounters Severe Symptoms of Malaria
# begin to match headline 385: Will Hepatitis B vaccine help La Paz?
# begin to match headline 386: Zika Outbreak in Puducherry
# begin to match headline 387: More Zika patients reported in Carrollton
# begin to match headline 388: Will Rabies vaccine help Tangier?
# begin to match headline 389: Zika symptoms spotted in Iquitos
# begin to match headline 390: West Nile Virus Exposure in Racine
# begin to match headline 391: The Spread of Hepatitis E in Lansing has been Confirmed
# begin to match headline 392: West Nile Virus Exposure in Alpharetta
# begin to match headline 393: Pedro Juan Caballero Encounters Severe Symptoms of Pneumonia
# begin to match headline 394: More Zika patients reported in Melbourne
# begin to match headline 395: Zika Troubles come to La Libertad
# begin to match headline 396: Herpes Vaccine is now Required in Mattoon
# begin to match headline 397: Kent is infested with Rabies
# begin to match headline 398: Zika symptoms spotted in Bonita Springs
# begin to match headline 399: The Spread of Malaria in Brazzaville has been Confirmed
# begin to match headline 400: More Zika patients reported in Fort Myers
# begin to match headline 401: Zika spreads to Lewisville
# begin to match headline 402: Ogden is infested with Gonorrhea
# begin to match headline 403: Fort Hood Reports its First Zika Patient
# begin to match headline 404: Huzhou Residents Receive Hepatitis B vaccine
# begin to match headline 405: New medicine wipes out Rabies in Newburgh
# begin to match headline 406: Iowa City Encounters Severe Symptoms of Rhinovirus
# begin to match headline 407: Spike of Rabies Cases in Managua
# begin to match headline 408: Outbreak of Zika in Santa Elena
# begin to match headline 409: Mumps Hits Howard Beach
# begin to match headline 410: The Spread of Gonorrhea in Reno has been Confirmed
# begin to match headline 411: How to Avoid Rhinovirus in Plainfield
# begin to match headline 412: Rumors about Varicella spreading in Carlsbad have been refuted
# begin to match headline 413: Scranton authorities confirmed the spread of Gonorrhea
# begin to match headline 414: Mad Cow Disease Disastrous to Brussels
# begin to match headline 415: Zika spreads to Olinda
# begin to match headline 416: Hallandale Beach a Victim of Zika Outbreak
# begin to match headline 417: Rhinovirus re-emerges in Storrs
# begin to match headline 418: Germantown authorities confirmed the spread of Chickenpox
# begin to match headline 419: Rumors about Rotavirus spreading in North Platte have been refuted
# begin to match headline 420: Spike of Hepatitis C Cases in Golden
# begin to match headline 421: Authorities are Worried about the Spread of Hepatitis D in Ganja
# begin to match headline 422: Dengue Exposure in Kathmandu
# begin to match headline 423: Tuberculosis has Arrived in Fairfield
# begin to match headline 424: Outbreak of Zika in Kozhikode
# begin to match headline 425: Bronchitis Symptoms Spread all over Santa Fe
# begin to match headline 426: More Patients in Alexandria are Getting Diagnosed with Mumps
# begin to match headline 427: Pneumonia Exposure in Alhambra
# begin to match headline 428: Hepatitis C re-emerges in Damascus
# begin to match headline 429: Lower Hospitalization in Pekanbaru after Rotavirus Vaccine becomes Mandatory
# begin to match headline 430: Spike of Meningitis Cases in Druid Hills
# begin to match headline 431: Schools in Bentonville Closed Due to Hepatitis B Outbreak
# begin to match headline 432: Hepatitis E Hits Hammond
# begin to match headline 433: Schools in Bridgeton Closed Due to Mumps Outbreak
# begin to match headline 434: Biloxi Residents Recieve Chlamydia vaccine
# begin to match headline 435: Case of Mad Cow Disease Reported in Hilden
# begin to match headline 436: Rumors about Rabies Spreading in Khartoum have been Refuted
# begin to match headline 437: Harare is infested with Pneumonia
# begin to match headline 438: Zika symptoms spotted in Sibu
# begin to match headline 439: Zika arrives in Quezon
# begin to match headline 440: More Patients in Crawfordsville are Getting Diagnosed with Rabies
# begin to match headline 441: Spike of Hepatitis B Cases in Greenville
# begin to match headline 442: Authorities are Worried about the Spread of Hepatitis D in Akron
# begin to match headline 443: More Zika patients reported in Nuevo Laredo
# begin to match headline 444: Bronchitis Keeps Spreading in San Mateo
# begin to match headline 445: Zika arrives in Boca Raton
# begin to match headline 446: Bradenton Experiences Zika Troubles
# begin to match headline 447: Chlamydia Symptoms Spread all over University City
# begin to match headline 448: Wisconsin Rapids Patient in Critical Condition after Contracting Chickenpox
# begin to match headline 449: Zika spreads to Kissimmee
# begin to match headline 450: Herpes Symptoms Spread all over Fremont
# begin to match headline 451: Spike of Pneumonia Cases in The Bronx
# begin to match headline 452: Authorities are Worried about the Spread of Hepatitis D in North Bay
# begin to match headline 453: The Spread of Herpes in Baku has been Confirmed
# begin to match headline 454: Will Measles vaccine help Sochi?
# begin to match headline 455: Tuberculosis Symptoms Spread all over Caguas
# begin to match headline 456: HIV has Arrived in Tacoma
# begin to match headline 457: Malaria re-emerges in Nashua
# begin to match headline 458: Arvada is infested with Syphilis
# begin to match headline 459: Spike of Syphilis Cases in West Monroe
# begin to match headline 460: More Zika patients reported in Ribeirao Preto
# begin to match headline 461: Martinsville tests new cure for Measles
# begin to match headline 462: Deerfield tests new cure for Measles
# begin to match headline 463: Contaminated Meat Brings Trouble for Bonn Farmers
# begin to match headline 464: More Patients in Magnolia are Getting Diagnosed with Malaria
# begin to match headline 465: Hepatitis A re-emerges in Foster City
# begin to match headline 466: How to Avoid Tuberculosis in Santa Monica
# begin to match headline 467: Zika reported in Fort Pierce
# begin to match headline 468: Authorities are Worried about the Spread of Syphilis in Pyongyang
# begin to match headline 469: Zika spreads to Winter Park
# begin to match headline 470: Durango is infested with Hepatitis B
# begin to match headline 471: Hepatitis A has not Left Staten Island
# begin to match headline 472: Mpika authorities confirmed the spread of Chikungunya
# begin to match headline 473: Gladstone Encounters Severe Symptoms of Dengue
# begin to match headline 474: Mad Cow Disease Hits London
# begin to match headline 475: New Milford Patient in Critical Condition after Contracting Respiratory Syncytial Virus
# begin to match headline 476: More people in Palo Alto are infected with HIV every year
# begin to match headline 477: HIV Symptoms Spread all over Hinthada
# begin to match headline 478: Zika symptoms spotted in Quito
# begin to match headline 479: Vineland authorities confirmed the spread of Chlamydia
# begin to match headline 480: Sulu, Zamboanga brace for Zika
# begin to match headline 481: More Zika patients reported in Custodia
# begin to match headline 482: Tupelo Residents Recieve Syphilis vaccine
# begin to match headline 483: Rumors about Syphilis spreading in Penal have been refuted
# begin to match headline 484: Spanish Flu Outbreak in Lisbon
# begin to match headline 485: Spanish Flu Spreading through Madrid
# begin to match headline 486: Barcelona Struck by Spanish Flu
# begin to match headline 487: The Spread of Dengue in Yakima has been Confirmed
# begin to match headline 488: Tuberculosis Hits Luanda
# begin to match headline 489: Will West Nile Virus vaccine help Dumai?
# begin to match headline 490: Rumors about Chlamydia spreading in Redmond have been refuted
# begin to match headline 491: Case of Varicella Reported in Concord
# begin to match headline 492: Zika virus case reported in Rockland
# begin to match headline 493: Zika investigators coming to Mankato
# begin to match headline 494: Toms River Encounters Severe Symptoms of Respiratory Syncytial Virus
# begin to match headline 495: The Spread of Malaria in Zanzibar has been Confirmed
# begin to match headline 496: Malaria Outbreak Hits Zanzibar's Tourist Industry
# begin to match headline 497: Tourist Perishes from Malaria in Arusha
# begin to match headline 498: Herpes Symptoms Spread all over New Kingston
# begin to match headline 499: More people in Yokohama are infected with Norovirus every year
# begin to match headline 500: More people in Kitwe are infected with Respiratory Syncytial Virus every year
# begin to match headline 501: Hepatitis D Keeps Spreading in Bismarck
# begin to match headline 502: Varicella Outbreak in Minot
# begin to match headline 503: Malaria has Arrived in Terrebonne
# begin to match headline 504: Chikungunya Keeps Spreading in North Vancouver
# begin to match headline 505: Authorities are Worried about the Spread of Chickenpox in Hemet
# begin to match headline 506: Fort Belvoir tests new cure for Hepatitis C
# begin to match headline 507: More people in Oak Brook are infected with Respiratory Syncytial Virus every year
# begin to match headline 508: Rumors about Hepatitis C spreading in Darien have been refuted
# begin to match headline 509: The Spread of West Nile Virus in Fairfield has been Confirmed
# begin to match headline 510: Princeton Encounters Severe Symptoms of Dengue
# begin to match headline 511: Norovirus Keeps Spreading in Copenhagen
# begin to match headline 512: Wuhan is infested with Varicella
# begin to match headline 513: Zika spreads to San Luis Potosi
# begin to match headline 514: Outbreak of Zika in Hutchins
# begin to match headline 515: Spike of Norovirus Cases in Canberra
# begin to match headline 516: Zika Troubles come to Greater Noida
# begin to match headline 517: Lower Hospitalization in Palm Springs after Hepatitis A Vaccine becomes Mandatory
# begin to match headline 518: Longwood volunteers spreading Zika awareness
# begin to match headline 519: Outbreak of Zika in Leesburg
# begin to match headline 520: Authorities are Worried about the Spread of Tuberculosis in Cantu
# begin to match headline 521: Zika symptoms spotted in Quixere
# begin to match headline 522: New medicine wipes out HIV in Kihei
# begin to match headline 523: Sangre Grande Residents Recieve Gonorrhea vaccine
# begin to match headline 524: Outbreak of Zika in Colombo
# begin to match headline 525: Will Rotavirus vaccine help Addis Ababa?
# begin to match headline 526: Stony Brook University experts discuss Zika virus
# begin to match headline 527: Lower Hospitalization in Janesville after Varicella Vaccine becomes Mandatory
# begin to match headline 528: Rabies Outbreak in Altus
# begin to match headline 529: Miami resident suggests Zika precautions
# begin to match headline 530: Zika Troubles come to Jaen
# begin to match headline 531: Hepatitis B Exposure in Edinburgh
# begin to match headline 532: Zika case reported in Reynosa
# begin to match headline 533: Schools in Tulare Closed Due to Mumps Outbreak
# begin to match headline 534: More Zika patients reported in Chennai
# begin to match headline 535: Hepatitis D Keeps Spreading in Danvers
# begin to match headline 536: Authorities a Miami
# begin to match headline 537: Zika case reported in Medellin
# begin to match headline 538: Spike of Tuberculosis Cases in Albuquerque
# begin to match headline 539: More people in Cranford are infected with Hepatitis A every year
# begin to match headline 540: West Nile Virus Hits Monroe
# begin to match headline 541: Pneumonia Outbreak in Springville
# begin to match headline 542: Zika arrives in San Onofre
# begin to match headline 543: Lung Cancer Rates Increasing in Moscow
# begin to match headline 544: Rumors about Rotavirus Spreading in Joliet have been Refuted
# begin to match headline 545: More Zika patients reported in Chanthaburi
# begin to match headline 546: Lawrenceville is infested with Dengue
# begin to match headline 547: Zika Reported in Ciudad Acuna
# begin to match headline 548: Zika case reported in Limoeiro
# begin to match headline 549: Ibadan tests new cure for Malaria
# begin to match headline 550: Gonorrhea has Arrived in Avon Lake
# begin to match headline 551: Pneumonia has not Left Kinshasa
# begin to match headline 552: Respiratory Syncytial Virus Hits Henderson
# begin to match headline 553: More Zika patients reported in Lakeland
# begin to match headline 554: Malaria Vaccine is now Required in Winona
# begin to match headline 555: More Patients in Canton are Getting Diagnosed with Norovirus
# begin to match headline 556: Ronkonkoma is infested with Chickenpox
# begin to match headline 557: Kedougou tests new cure for Hepatitis C
# begin to match headline 558: Gonorrhea Exposure in Norwalk
# begin to match headline 559: How to Avoid Rhinovirus in Medford
# begin to match headline 560: Hepatitis D Symptoms Spread all over Evansville
# begin to match headline 561: New medicine wipes out Herpes in Bossier City
# begin to match headline 562: Pneumonia Exposure in San Jose
# begin to match headline 563: Authorities are Worried about the Spread of Mad Cow Disease in Edinburgh
# begin to match headline 564: Duluth Patient in Critical Condition after Contracting Rotavirus
# begin to match headline 565: Measles Hits Davos
# begin to match headline 566: Norfolk tests new cure for Herpes
# begin to match headline 567: More Zika patients reported in Botucatu
# begin to match headline 568: Manassas Encounters Severe Symptoms of Measles
# begin to match headline 569: Fayetteville authorities confirmed the spread of HIV
# begin to match headline 570: Varicella Exposure in Cambridge
# begin to match headline 571: Hepatitis A Vaccine is now Required in Fukushima
# begin to match headline 572: Zika Outbreak in South Miami
# begin to match headline 573: Hepatitis D Symptoms Spread all over North Bethesda
# begin to match headline 574: Panama Cityas first Zika related death
# begin to match headline 575: West Nile Virus has Arrived in Dongguan
# begin to match headline 576: Zika arrives in Belmopan
# begin to match headline 577: Zika seminars in Yuma County
# begin to match headline 578: Rumors about Hepatitis E Spreading in Morristown have been Refuted
# begin to match headline 579: Mumps Outbreak in Joplin
# begin to match headline 580: Spike of Hepatitis E Cases in Morehead City
# begin to match headline 581: Authorities are Worried about the Spread of Mumps in Corona
# begin to match headline 582: Schools in Danville Closed Due to Tuberculosis Outbreak
# begin to match headline 583: Outbreak of Zika in Alvorada
# begin to match headline 584: Marquette tests new cure for Hepatitis A
# begin to match headline 585: Norovirus Vaccine is now Required in Anaheim
# begin to match headline 586: Zika Outbreak in Manaus
# begin to match headline 587: Zika spreads to Caucasia
# begin to match headline 588: Case of Malaria Reported in Aurora
# begin to match headline 589: Manchester Residents Recieve Influenza vaccine
# begin to match headline 590: Zika spreads to Kamphaeng Phet
# begin to match headline 591: Rotavirus Vaccine is now Required in Labasa
# begin to match headline 592: The Spread of Hepatitis E in Fargo has been Confirmed
# begin to match headline 593: Zika Outbreak in Mexicali
# begin to match headline 594: West Nile Virus Keeps Spreading in Hauppauge
# begin to match headline 595: Bronchitis Keeps Spreading in Hayward
# begin to match headline 596: Schools in Coamo Closed Due to Rhinovirus Outbreak
# begin to match headline 597: Zika arrives in Dangriga
# begin to match headline 598: Zika spreads to Plant City
# begin to match headline 599: Chlamydia Exposure in Sanaa
# begin to match headline 600: Zika Reported in North Miami Beach
# begin to match headline 601: More Patients in Kensington are Getting Diagnosed with Varicella
# begin to match headline 602: More Patients in Maynard are Getting Diagnosed with Syphilis
# begin to match headline 603: Case of West Nile Virus Reported in Riverside
# begin to match headline 604: Northfield Encounters Severe Symptoms of Herpes
# begin to match headline 605: The Spread of Respiratory Syncytial Virus in Monroe has been Confirmed
# begin to match headline 606: How to Avoid Hepatitis B in Trenton
# begin to match headline 607: Zika Reported in Ilopango
# begin to match headline 608: Barstow Patient in Critical Condition after Contracting Herpes
# begin to match headline 609: Hepatitis D Exposure in Aswan
# begin to match headline 610: Will Gonorrhea vaccine help East Moline?
# begin to match headline 611: New medicine wipes out Influenza in Redlands
# begin to match headline 612: How to Avoid Contaminated Meat when Visiting Basel
# begin to match headline 613: More Zika patients reported in Kampong Speu
# begin to match headline 614: Alameda Residents Recieve Rabies vaccine
# begin to match headline 615: Mad Cow Disease Detected in Lyon
# begin to match headline 616: Memphis Encounters Severe Symptoms of Swine Flu
# begin to match headline 617: Zika Troubles come to Delray Beach
# begin to match headline 618: How to Avoid Chikungunya in Hampton
# begin to match headline 619: Zika Reported in Sao Jose
# begin to match headline 620: Case of Norovirus Reported in Stratford
# begin to match headline 621: How to Avoid Hepatitis E in South Bend
# begin to match headline 622: Hepatitis C Outbreak in Bethlehem
# begin to match headline 623: Davenport is infested with Dengue
# begin to match headline 624: Rumors about Swine Flu spreading in Suzhou have been refuted
# begin to match headline 625: Malaria Vaccine is now Required in Elyria
# begin to match headline 626: Zika case reported in Antioquia
# begin to match headline 627: Case of Swine Flu Reported in Tbilisi
# begin to match headline 628: Chikungunya has not Left Pismo Beach
# begin to match headline 629: Zika spreads to La Joya
# begin to match headline 630: Influenza Keeps Spreading in Suffolk
# begin to match headline 631: More people in Allentown are infected with Chlamydia every year
# begin to match headline 632: Mad Cow Disease re-emerges in Bedford
# begin to match headline 633: Authorities are Worried about the Spread of Hepatitis B in Yiwu
# begin to match headline 634: Zika Outbreak in Yurimaguas
# begin to match headline 635: Dengue Outbreak in Easton
# begin to match headline 636: Varicella has Arrived in Milton
# begin to match headline 637: New medicine wipes out Meningitis in Sevilla
# begin to match headline 638: Authorities are Worried about the Spread of Varicella in Clovis
# begin to match headline 639: More Zika patients reported in Fort Worth
# begin to match headline 640: Zika symptoms spotted in Boynton Beach
# begin to match headline 641: Outbreak of Zika in Portoviejo
# begin to match headline 642: Influenza Exposure in Muscat
# begin to match headline 643: Rumors about Rabies spreading in Jerusalem have been refuted
# begin to match headline 644: More Zika patients reported in Indang
# begin to match headline 645: Suva authorities confirmed the spread of Rotavirus
# begin to match headline 646: More Zika patients reported in Bella Vista
# begin to match headline 647: Zika Outbreak in Wichita Falls
#                         headline  city        country
# count                        647   624            624
# unique                       647   584             98
# top     Zika Outbreak Hits Miami  Mori  United States
# freq                           1     7            313
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 647 entries, 0 to 646
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   headline  647 non-null    object
#  1   city      624 non-null    object
#  2   country   624 non-null    object
# dtypes: object(3)
# memory usage: 15.3+ KB
# None
#                                               headline  city country
# 88            Maka City Experiences Influenza Outbreak  None    None
# 156            West Nile Virus Outbreak in Saint Johns  None    None
# 234                         Malaria Exposure in Sussex  None    None
# 248              Greenwich Establishes Zika Task Force  None    None
# 252         Will West Nile Virus vaccine help Parsons?  None    None
# 257          Yulee takes a hit from Spreading Sickness  None    None
# 270  The Spread of Chikungunya in Davidson has been...  None    None
# 286                  Zika case reported in Los Fresnos  None    None
# 327                   Bronchitis Outbreak in Manhasset  None    None
# 339              Zika Troubles come to Padre Las Casas  None    None
# 342  Rumors about Influenza Spreading in Dobbs Ferr...  None    None
# 352                         Outbreak of Zika in Destin  None    None
# 379  Gympie Patient in Critical Condition after Con...  None    None
# 429           Spike of Meningitis Cases in Druid Hills  None    None
# 482  Rumors about Syphilis spreading in Penal have ...  None    None
# 505        Fort Belvoir tests new cure for Hepatitis C  None    None
# 513                       Outbreak of Zika in Hutchins  None    None
# 517       Longwood volunteers spreading Zika awareness  None    None
# 520                   Zika symptoms spotted in Quixere  None    None
# 564                                 Measles Hits Davos  None    None
# 579        Spike of Hepatitis E Cases in Morehead City  None    None
# 596                           Zika arrives in Dangriga  None    None
# 627               Chikungunya has not Left Pismo Beach  None    None
# 总共用时 6094.092916 秒
